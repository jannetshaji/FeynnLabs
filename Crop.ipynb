# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.cluster.hierarchy import dendrogram, linkage
import seaborn as sns

# %%
df=pd.read_csv('/content/crop_production.csv')

# %%
max_crop_production = df.groupby('State_Name')['Production'].idxmax()
table_data = df.loc[max_crop_production, ['State_Name', 'Production']]

# %%
print(table_data)
# Out:
#                          State_Name    Production
# 77      Andaman and Nicobar Islands  7.130000e+07
# 2543                 Andhra Pradesh  7.801620e+08
# 10054             Arunachal Pradesh  3.501000e+04
# 23827                         Assam  6.071900e+07
# 39340                         Bihar  9.614539e+06
# 45898                    Chandigarh  3.960000e+03
# 46358                  Chhattisgarh  2.129180e+06
# 56778        Dadra and Nagar Haveli  1.229600e+05
# 57092                           Goa  7.141000e+07
# 64203                       Gujarat  1.175400e+07
# 71340                       Haryana  2.894000e+06
# 72236              Himachal Pradesh  1.702830e+05
# 74495            Jammu and Kashmir   2.093900e+05
# 76472                     Jharkhand  5.095690e+05
# 79070                     Karnataka  1.802747e+07
# 100654                       Kerala  1.125000e+09
# 115776               Madhya Pradesh  1.545480e+06
# 136558                  Maharashtra  2.004970e+07
# ...

# %%
df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
max_crop_production = df.groupby('State_Name')['Production'].idxmax()
table_data = df.loc[max_crop_production, ['State_Name', 'Production']]

# %%
table = plt.table(cellText=table_data.values, colLabels=table_data.columns, loc='center')

# %%
plt.figure(figsize=(10, 10))
plt.bar(table_data['State_Name'], table_data['Production'], color='green')
plt.xticks(rotation=90, ha='right', fontsize=10)
plt.title('Production vs States')
# Out:
# Text(0.5, 1.0, 'Production vs States')

# %%
max_crop_production = df.groupby('State_Name')['Production'].idxmax()
table_data = df.loc[max_crop_production, ['State_Name', 'Production']]

# %%
sorted_df = df.sort_values('Production', ascending=False)

# %%
plt.figure(figsize=(10, 10))
plt.xticks(rotation=90, ha='right', fontsize=10)
plt.pie(table_data['Production'], labels=table_data['State_Name'], autopct='%1.1f%%',startangle=90)
plt.title('Piechart of Production')
# Out:
# Text(0.5, 1.0, 'Piechart of Production')

# %%
correlation_matrix = df.corr()
# Out:
# <ipython-input-52-68bbfff3c4eb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='BuPu')
plt.title('Correlation Heatmap of Area Production and Crop year')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Area Production and Crop year')

# %%
df = pd.read_csv('/content/crop_production.csv')
x = df['State_Name']
y = df['Area']
plt.figure(figsize=(10, 10))
plt.plot(x, y)
plt.xticks(rotation=35, ha='right', fontsize=10)
plt.xlabel('State_Name')
plt.ylabel('Area')
plt.title('Line Plot')
plt.show()
